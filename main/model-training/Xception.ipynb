# %%
import tensorflow as tf

base_model = tf.keras.applications.Xception(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(512, 512, 3),
    include_top=False)  # Do not include the ImageNet classifier at the top.
base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 255, 255, 32)         864       ['input_3[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 255, 255, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 255, 255, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 253, 253, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 253, 253, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 253, 253, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 253, 253, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 253, 253, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 253, 253, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 253, 253, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 253, 253, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_8 (Conv2D)           (None, 127, 127, 128)        8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 127, 127, 128)        0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_8 (Bat  (None, 127, 127, 128)        512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  add_24 (Add)                (None, 127, 127, 128)        0         ['block2_pool[0][0]',
#                                                                      'batch_normalization_8[0][0]'
#                                                                     ]
#
#  block3_sepconv1_act (Activ  (None, 127, 127, 128)        0         ['add_24[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 127, 127, 256)        33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 127, 127, 256)        1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 127, 127, 256)        0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 127, 127, 256)        67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 127, 127, 256)        1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 256)          32768     ['add_24[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 64, 64, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_9 (Bat  (None, 64, 64, 256)          1024      ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_25 (Add)                (None, 64, 64, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_9[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 64, 64, 256)          0         ['add_25[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 64, 64, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 64, 64, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 64, 64, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 64, 64, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 64, 64, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 728)          186368    ['add_25[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 32, 32, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_10 (Ba  (None, 32, 32, 728)          2912      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  add_26 (Add)                (None, 32, 32, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_10[0][0]
#                                                                     ']
#
#  block5_sepconv1_act (Activ  (None, 32, 32, 728)          0         ['add_26[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 32, 32, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 32, 32, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 32, 32, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 32, 32, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 32, 32, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 32, 32, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 32, 32, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 32, 32, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_27 (Add)                (None, 32, 32, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_26[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 32, 32, 728)          0         ['add_27[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 32, 32, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 32, 32, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 32, 32, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 32, 32, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 32, 32, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 32, 32, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 32, 32, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 32, 32, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_28 (Add)                (None, 32, 32, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_27[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 32, 32, 728)          0         ['add_28[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 32, 32, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 32, 32, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 32, 32, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 32, 32, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 32, 32, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 32, 32, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 32, 32, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 32, 32, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_29 (Add)                (None, 32, 32, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_28[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 32, 32, 728)          0         ['add_29[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 32, 32, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 32, 32, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 32, 32, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 32, 32, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 32, 32, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 32, 32, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 32, 32, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 32, 32, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_30 (Add)                (None, 32, 32, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_29[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 32, 32, 728)          0         ['add_30[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 32, 32, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 32, 32, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 32, 32, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 32, 32, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 32, 32, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 32, 32, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 32, 32, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 32, 32, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_31 (Add)                (None, 32, 32, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_30[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 32, 32, 728)          0         ['add_31[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 32, 32, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 32, 32, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 32, 32, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 32, 32, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 32, 32, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 32, 32, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 32, 32, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 32, 32, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_32 (Add)                (None, 32, 32, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_31[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 32, 32, 728)          0         ['add_32[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 32, 32, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 32, 32, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 32, 32, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 32, 32, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 32, 32, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 32, 32, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 32, 32, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 32, 32, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_33 (Add)                (None, 32, 32, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_32[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 32, 32, 728)          0         ['add_33[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 32, 32, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 32, 32, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 32, 32, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 32, 32, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 32, 32, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 32, 32, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 32, 32, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 32, 32, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_34 (Add)                (None, 32, 32, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_33[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 32, 32, 728)          0         ['add_34[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 32, 32, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 32, 32, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 32, 32, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 32, 32, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 32, 32, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 1024)         745472    ['add_34[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 16, 16, 1024)         0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_11 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  add_35 (Add)                (None, 16, 16, 1024)         0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ']
#
#  block14_sepconv1 (Separabl  (None, 16, 16, 1536)         1582080   ['add_35[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 16, 16, 1536)         6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 16, 16, 1536)         0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 16, 16, 2048)         3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 16, 16, 2048)         8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 16, 16, 2048)         0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
# ==================================================================================================
# Total params: 20861480 (79.58 MB)
# Trainable params: 20806952 (79.37 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________
